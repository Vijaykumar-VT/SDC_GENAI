# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaykumar-VT/SDC_GENAI/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from youtube_transcript_api import YouTubeTranscriptApi
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# 1. Extract Transcript from YouTube Video
def get_transcript(video_id):
    transcript = YouTubeTranscriptApi.get_transcript(video_id)
    return " ".join([entry['text'] for entry in transcript])

# 2. Split Transcript into Chunks
def split_text(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    return splitter.split_text(text)

# 3. Create FAISS Vector Store
def create_vector_store(chunks):
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(chunks, embeddings)

# 4. Initialize RAG Pipeline
def initialize_rag(vector_store):
    retriever = vector_store.as_retriever()
    llm = ChatOpenAI(temperature=0)
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# 5. Main Function
def summarize_youtube_video(video_url):
    video_id = video_url.split("v=")[-1]
    transcript = get_transcript(video_id)
    chunks = split_text(transcript)
    vector_store = create_vector_store(chunks)
    qa_chain = initialize_rag(vector_store)
    summary = qa_chain.run("Provide a concise summary of the video.")
    return summary

# Example Usage
if __name__ == "__main__":
    video_url = "https://www.youtube.com/watch?v=VIDEO_ID"
    summary = summarize_youtube_video(video_url)
    print("Video Summary:\n", summary)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-be9a93a05fa8> in <cell line: 0>()
#       1 import os
# ----> 2 from youtube_transcript_api import YouTubeTranscriptApi
#       3 from langchain.embeddings import OpenAIEmbeddings
#       4 from langchain.vectorstores import FAISS
#       5 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# YouTube Video Summarizer using RAG (LangChain + OpenAI + FAISS)
# Prerequisites: pip install openai langchain faiss-cpu youtube-transcript-api

import os
from youtube_transcript_api import YouTubeTranscriptApi
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = "AIzaSyDe4RmBrb7Xm0XSt-whbkgsBuWmqr06lug"

def get_transcript(video_url):
    try:
        video_id = video_url.split("v=")[-1]
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        full_text = " ".join([entry['text'] for entry in transcript])
        return full_text
    except Exception as e:
        print("Transcript fetch error:", e)
        return ""

def split_into_chunks(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    return splitter.split_text(text)

def build_vectorstore(chunks):
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(chunks, embeddings)

def build_rag_chain(vectorstore):
    retriever = vectorstore.as_retriever()
    llm = ChatOpenAI(temperature=0)
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

def summarize_youtube_video(video_url):
    transcript = get_transcript(video_url)
    if not transcript:
        return "Transcript could not be retrieved."

    chunks = split_into_chunks(transcript)
    vectorstore = build_vectorstore(chunks)
    qa_chain = build_rag_chain(vectorstore)
    return qa_chain.run("Summarize the content of this YouTube video in simple terms.")

# Run the summarizer
if __name__ == "__main__":
    video_url = input("Enter YouTube video URL: ")
    summary = summarize_youtube_video(video_url)
    print("\n📄 Summary:\n", summary)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-81d356ae6270> in <cell line: 0>()
#       3
#       4 import os
# ----> 5 from youtube_transcript_api import YouTubeTranscriptApi
#       6 from langchain.embeddings import OpenAIEmbeddings
#       7 from langchain.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install missing dependencies if needed
try:
    from youtube_transcript_api import YouTubeTranscriptApi
except ImportError:
    import os
    os.system('pip install youtube-transcript-api')

try:
    from langchain.embeddings import OpenAIEmbeddings
    from langchain.vectorstores import FAISS
    from langchain.text_splitter import RecursiveCharacterTextSplitter
    from langchain.chat_models import ChatOpenAI
    from langchain.chains import RetrievalQA
except ImportError:
    import os
    os.system('pip install openai langchain faiss-cpu')

# Now import everything
from youtube_transcript_api import YouTubeTranscriptApi
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA
import os

# Set your OpenAI API Key
os.environ["OPENAI_API_KEY"] = "your-openai-api-key-here"  # <-- Replace this with your key

def get_transcript(video_url):
    try:
        video_id = video_url.split("v=")[-1]
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return " ".join([entry['text'] for entry in transcript])
    except Exception as e:
        return f"Error retrieving transcript: {e}"

def split_text(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    return splitter.split_text(text)

def create_vectorstore(chunks):
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(chunks, embeddings)

def create_rag_chain(vstore):
    retriever = vstore.as_retriever()
    llm = ChatOpenAI(temperature=0)
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

def summarize_youtube_video(url):
    transcript = get_transcript(url)
    if transcript.startswith("Error"):
        return transcript
    chunks = split_text(transcript)
    vstore = create_vectorstore(chunks)
    qa = create_rag_chain(vstore)
    return qa.run("Summarize this video in simple terms.")

# === Run ===
if __name__ == "__main__":
    url = input("Enter YouTube video URL: ")
    summary = summarize_youtube_video(url)
    print("\n📄 Summary:\n", summary)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/langchain/_api/module_import.py in import_by_name(name)
#      68             try:
# ---> 69                 module = importlib.import_module(new_module)
#      70             except ModuleNotFoundError as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ...

# %%
# Auto-install missing packages
import os

try:
    from youtube_transcript_api import YouTubeTranscriptApi
except ImportError:
    os.system("pip install youtube-transcript-api")

try:
    from langchain_community.vectorstores import FAISS
    from langchain_community.embeddings import OpenAIEmbeddings
    from langchain.text_splitter import RecursiveCharacterTextSplitter
    from langchain.chat_models import ChatOpenAI
    from langchain.chains import RetrievalQA
except ImportError:
    os.system("pip install -U langchain langchain-community faiss-cpu openai")

# Re-import after installation
from youtube_transcript_api import YouTubeTranscriptApi
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# Set your OpenAI API key
os.environ["OPENAI_API_KEY"] = "your-openai-api-key"  # Replace with your actual key

def get_transcript(video_url):
    try:
        video_id = video_url.split("v=")[-1]
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return " ".join([entry["text"] for entry in transcript])
    except Exception as e:
        return f"❌ Error retrieving transcript: {e}"

def split_text(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    return splitter.split_text(text)

def create_vectorstore(chunks):
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(chunks, embeddings)

def create_rag_chain(vstore):
    retriever = vstore.as_retriever()
    llm = ChatOpenAI(temperature=0)
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

def summarize_youtube_video(url):
    transcript = get_transcript(url)
    if transcript.startswith("❌"):
        return transcript
    chunks = split_text(transcript)
    vstore = create_vectorstore(chunks)
    qa = create_rag_chain(vstore)
    return qa.run("Summarize this YouTube video in simple terms.")

# === Run it ===
if __name__ == "__main__":
    url = input("🎥 Enter YouTube video URL: ")
    summary = summarize_youtube_video(url)
    print("\n📄 Summary:\n", summary)
# Out:
# 🎥 Enter YouTube video URL: ben ten
#
# 📄 Summary:
#  ❌ Error retrieving transcript:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ben ten! This is most likely caused by:
#
# The video is no longer available
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!

# %%
# === Install required packages if not already installed ===
import os

# Install missing packages
os.system("pip install -q youtube-transcript-api langchain langchain-community faiss-cpu openai")

# === Imports ===
from youtube_transcript_api import YouTubeTranscriptApi
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# === Set your OpenAI API key ===
os.environ["OPENAI_API_KEY"] = "your-openai-api-key"  # 🔐 Replace with your actual API key

# === Function: Get transcript from YouTube ===
def get_transcript(video_url):
    try:
        video_id = video_url.split("v=")[-1]
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return " ".join([entry['text'] for entry in transcript])
    except Exception as e:
        return f"❌ Transcript fetch error: {e}"

# === Function: Split into chunks for embedding ===
def split_into_chunks(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    return splitter.split_text(text)

# === Function: Create FAISS vector store ===
def create_vector_store(chunks):
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(chunks, embeddings)

# === Function: Build RAG pipeline ===
def build_rag_chain(vector_store):
    retriever = vector_store.as_retriever()
    llm = ChatOpenAI(temperature=0)
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# === Main Function: Summarize the video ===
def summarize_youtube_video(video_url):
    print("📥 Fetching transcript...")
    transcript = get_transcript(video_url)
    if transcript.startswith("❌"):
        return transcript

    print("✂️ Splitting transcript...")
    chunks = split_into_chunks(transcript)

    print("📦 Creating vector store...")
    vector_store = create_vector_store(chunks)

    print("🧠 Generating summary using RAG...")
    qa_chain = build_rag_chain(vector_store)
    summary = qa_chain.run("Give a short and clear summary of this video.")
    return summary

# === Run Script ===
if __name__ == "__main__":
    url = input("🎥 Enter YouTube video URL: ")
    summary = summarize_youtube_video(url)
    print("\n📄 Summary:\n", summary)
# Out:
# 🎥 Enter YouTube video URL: https://www.youtube.com/watch?v=I5kj-YsmWjM
# 📥 Fetching transcript...
# ✂️ Splitting transcript...
# 📦 Creating vector store...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/langchain_community/embeddings/openai.py in _get_len_safe_embeddings(self, texts, engine, chunk_size)
#     452             try:
# --> 453                 import tiktoken
#     454             except ImportError:
#
# ModuleNotFoundError: No module named 'tiktoken'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-a29e1b4d1ae4> in <cell line: 0>()
#      62 if __name__ == "__main__":
#      63     url = input("🎥 Enter YouTube video URL: ")
# ---> 64     summary = summarize_youtube_video(url)
# ...

# %%
# === Auto-install missing packages if not already installed ===
import os

# Install missing packages
os.system("pip install -q youtube-transcript-api langchain langchain-community faiss-cpu openai tiktoken")

# === Imports ===
from youtube_transcript_api import YouTubeTranscriptApi
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# === Set your OpenAI API key ===
os.environ["OPENAI_API_KEY"] = "your-openai-api-key"  # 🔐 Replace with your actual API key

# === Function: Get transcript from YouTube ===
def get_transcript(video_url):
    try:
        video_id = video_url.split("v=")[-1]
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        return " ".join([entry['text'] for entry in transcript])
    except Exception as e:
        return f"❌ Transcript fetch error: {e}"

# === Function: Split into chunks for embedding ===
def split_into_chunks(text):
    splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    return splitter.split_text(text)

# === Function: Create FAISS vector store ===
def create_vector_store(chunks):
    embeddings = OpenAIEmbeddings()
    return FAISS.from_texts(chunks, embeddings)

# === Function: Build RAG pipeline ===
def build_rag_chain(vector_store):
    retriever = vector_store.as_retriever()
    llm = ChatOpenAI(temperature=0)
    return RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# === Main Function: Summarize the video ===
def summarize_youtube_video(video_url):
    print("📥 Fetching transcript...")
    transcript = get_transcript(video_url)
    if transcript.startswith("❌"):
        return transcript

    print("✂️ Splitting transcript...")
    chunks = split_into_chunks(transcript)

    print("📦 Creating vector store...")
    vector_store = create_vector_store(chunks)

    print("🧠 Generating summary using RAG...")
    qa_chain = build_rag_chain(vector_store)
    summary = qa_chain.run("Give a short and clear summary of this video.")
    return summary

# === Run Script ===
if __name__ == "__main__":
    url = input("🎥 Enter YouTube video URL: ")
    summary = summarize_youtube_video(url)
    print("\n📄 Summary:\n", summary)
# Out:
# 🎥 Enter YouTube video URL: https://www.youtube.com/watch?v=I5kj-YsmWjM
# 📥 Fetching transcript...
# ✂️ Splitting transcript...
# 📦 Creating vector store...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-10-8cd4d603c3df> in <cell line: 0>()
#      62 if __name__ == "__main__":
#      63     url = input("🎥 Enter YouTube video URL: ")
# ---> 64     summary = summarize_youtube_video(url)
#      65     print("\n📄 Summary:\n", summary)
#
# <ipython-input-10-8cd4d603c3df> in summarize_youtube_video(video_url)
#      52
#      53     print("📦 Creating vector store...")
# ---> 54     vector_store = create_vector_store(chunks)
#      55
#      56     print("🧠 Generating summary using RAG...")
#
# <ipython-input-10-8cd4d603c3df> in create_vector_store(chunks)
#      33 def create_vector_store(chunks):
#      34     embeddings = OpenAIEmbeddings()
# ...

# %%
import openai

# Set your OpenAI API Key
openai.api_key = 'your-openai-api-key'

def get_medical_answer(question):
    try:
        response = openai.Completion.create(
            engine="text-davinci-003",  # Or "gpt-3.5-turbo" for cheaper model
            prompt=f"Answer the following medical question: {question}",
            max_tokens=150
        )
        return response.choices[0].text.strip()
    except Exception as e:
        return f"Error: {e}"

# Example usage
question = input("Ask your medical question: ")
answer = get_medical_answer(question)
print(f"Answer: {answer}")
# Out:
# Ask your medical question: symptoms of fever
# Answer: Error:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742

# %% [markdown]
# pip install openai flask
# import openai
# from flask import Flask, request, jsonify
#
# # Set your OpenAI API key
# openai.api_key = 'your-openai-api-key'  # Replace with your actual OpenAI API key
#
# app = Flask(__name__)
#
# # Function to get response from GPT-3 for medical questions
# def get_medical_answer(question):
#     try:
#         response = openai.Completion.create(
#             engine="text-davinci-003",  # You can also use "gpt-3.5-turbo" if using a newer model
#             prompt=f"Answer the following medical question concisely: {question}",
#             max_tokens=150
#         )
#         return response.choices[0].text.strip()
#     except Exception as e:
#         return f"Error: {e}"
#
# # Route to handle user input and give a medical answer
# @app.route('/ask', methods=['POST'])
# def ask_question():
#     data = request.get_json()
#     question = data.get('question')
#
#     if question:
#         answer = get_medical_answer(question)
#         return jsonify({"answer": answer})
#     else:
#         return jsonify({"error": "No question provided"}), 400
#
# # Basic route to check if the server is working
# @app.route('/')
# def home():
#     return "Medical Q&A Chatbot is running!"
#
# if __name__ == '__main__':
#     app.run(debug=True)

# %%
# !pip install openai flask

# %%
import openai
from flask import Flask, request, jsonify

# Set your OpenAI API key
openai.api_key = 'your-openai-api-key'  # Replace with your actual OpenAI API key

app = Flask(__name__)

# Function to get response from GPT-3 for medical questions
def get_medical_answer(question):
    try:
        response = openai.Completion.create(
            engine="text-davinci-003",  # You can also use "gpt-3.5-turbo" if using a newer model
            prompt=f"Answer the following medical question concisely: {question}",
            max_tokens=150
        )
        return response.choices[0].text.strip()
    except Exception as e:
        return f"Error: {e}"

# Route to handle user input and give a medical answer
@app.route('/ask', methods=['POST'])
def ask_question():
    data = request.get_json()
    question = data.get('question')

    if question:
        answer = get_medical_answer(question)
        return jsonify({"answer": answer})
    else:
        return jsonify({"error": "No question provided"}), 400

# Basic route to check if the server is working
@app.route('/')
def home():
    return "Medical Q&A Chatbot is running!"

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat

# %%
import random
import nltk
from nltk.chat.util import Chat, reflections
from transformers import pipeline

# Define some basic medical queries and responses for NLTK-based chatbot
pairs = [
    (r"Hi|Hello|Hey", ["Hello! How can I assist you with your health today?", "Hi! How can I help you?"]),
    (r"How are you\?", ["I'm just a chatbot, but I'm doing great! How are you?"]),
    (r"Tell me about symptoms of flu",
     ["Flu symptoms usually include fever, chills, body aches, cough, and fatigue."]),
    (r"How do I treat a cold",
     ["For treating a cold, it is important to rest, stay hydrated, and take over-the-counter medications to relieve symptoms."]),
    (r"What is COVID-19?",
     ["COVID-19 is a contagious disease caused by the coronavirus SARS-CoV-2. It can cause symptoms like fever, cough, and shortness of breath."]),
    (r"How can I prevent high blood pressure?",
     ["You can prevent high blood pressure by maintaining a healthy diet, exercising regularly, and managing stress."]),
    (r"What should I eat for good health?",
     ["A balanced diet rich in fruits, vegetables, lean proteins, and whole grains can help you maintain good health."]),
    (r"Goodbye", ["Goodbye! Stay healthy and take care!"]),
]

# Initialize the NLTK-based chatbot with the pairs
chatbot = Chat(pairs, reflections)

# Initialize Hugging Face's GPT-2 model for advanced responses
chatbot_model = pipeline("text-generation", model="gpt2")

def medical_chatbot():
    print("Hello! I am your Medical AI Chatbot. How can I help you today?")
    while True:
        user_input = input("You: ")

        # Exit the chatbot loop
        if user_input.lower() == 'exit' or user_input.lower() == 'quit':
            print("Goodbye! Stay healthy and take care!")
            break

        # Try using NLTK chatbot for basic responses
        response = chatbot.respond(user_input)

        # If no response from NLTK chatbot, use GPT-2 for an advanced response
        if response is None:
            response = chatbot_model(user_input, max_length=100, num_return_sequences=1)[0]['generated_text']

        print(f"Bot: {response}")

# Main entry point
if __name__ == "__main__":
    nltk.download('punkt')  # Download required NLTK resources
    medical_chatbot()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %%
import requests
import xml.etree.ElementTree as ET
import nltk

# Initialize NLTK
nltk.download('punkt')

# PubMed API URL
BASE_URL = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"

# Define a function to query PubMed based on a search term
def query_pubmed(query, max_results=5):
    params = {
        'db': 'pubmed',
        'term': query,  # The query term (e.g., disease or medical topic)
        'retmax': max_results,  # Max number of results to fetch
        'retmode': 'xml'  # Return results in XML format
    }
    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        # Parse the XML response
        root = ET.fromstring(response.text)
        ids = [id_tag.text for id_tag in root.findall(".//Id")]
        return ids
    else:
        print("Error fetching data from PubMed.")
        return []

# Define a function to get detailed information about the articles from PubMed
def fetch_article_details(ids):
    details = []
    if ids:
        fetch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esummary.fcgi"
        for id in ids:
            params = {
                'db': 'pubmed',
                'id': id,
                'retmode': 'xml'
            }
            response = requests.get(fetch_url, params=params)
            if response.status_code == 200:
                root = ET.fromstring(response.text)
                docsum = root.find(".//DocSum")
                title = docsum.find(".//Item[@Name='Title']").text if docsum else "No Title"
                source = docsum.find(".//Item[@Name='Source']").text if docsum else "No Source"
                details.append({"title": title, "source": source})
            else:
                print("Error fetching article details.")
    return details

# Define a function for the chatbot interaction
def medical_chatbot():
    print("Hello! I am your Medical Q&A Chatbot. How can I assist you with medical information?")

    while True:
        user_input = input("You: ")

        # Exit condition
        if user_input.lower() in ['exit', 'quit']:
            print("Goodbye! Stay healthy and take care!")
            break

        # Query PubMed with the user's input
        print(f"Searching PubMed for: {user_input}")
        pub
